# %% [markdown]
# # Run TBEn Training
#
# This notebook is a thin launcher for the rewritten CLI pipeline.

# %%
CONFIG = "configs/tben/dinov2_q_rois_all.yaml"
SUBJECT = 1
OUTPUT_ROOT = "./results"
MAX_TRAIN_STEPS = 1

# %%
# !uv run python -m src.cli.inspect_data --dataset-root /data/algonauts_2023_challenge_data --subject {SUBJECT}

# %%
# !uv run python -m src.cli.train --config {CONFIG} --subject {SUBJECT} --output-root {OUTPUT_ROOT} --epochs 1 --max-train-steps {MAX_TRAIN_STEPS}
