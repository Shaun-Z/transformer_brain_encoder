# %% [markdown]
# # Wrapper Smoke Notebook
#
# Load a saved `.pth` artifact and run the rewritten wrapper.

# %%
import torch
from brain_encoder_wrapper import brain_encoder_wrapper

# %%
CHECKPOINT = "./results/subj01_dinov2_q_rois_all/last.pth"
SUBJECT = 1
model = brain_encoder_wrapper(checkpoint_path=CHECKPOINT, subject=SUBJECT)

# %%
images = torch.randn(2, 3, 434, 434)
lh_pred, rh_pred = model.forward(images)
lh_pred.shape, rh_pred.shape
